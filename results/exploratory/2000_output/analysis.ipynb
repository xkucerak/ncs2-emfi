# %%
import numpy as np

# %%
original = np.load(
    "0140_pulse_before_inference/pulse_before_inference_log/0.npy"
).squeeze(1)
sucess = np.load(
    "0140_pulse_before_inference/pulse_before_inference_log/2.npy"
).squeeze(1)

# %%
original.min(), original.max()

# %%
sucess.min(), sucess.max()

# %%
for a, b in zip(original, sucess):
    for i in a:
        print(i, end="")
    print()
    for i in b:
        print(i, end="")
    print()

# %%
original = np.load(
    "0141_pulse_after_inference/pulse_after_inference_log/0.npy"
).squeeze(1)
sucess = np.load("0141_pulse_after_inference/pulse_after_inference_log/18.npy").squeeze(
    1
)
# sucess = np.load("0141_pulse_after_inference/pulse_after_inference_log/13.npy").squeeze(
#     1
# )

# %%
original.min(), original.max(), np.average(original)
# Out:
# (np.float32(-9.21875), np.float32(34.0), np.float32(-0.003761417))

# %%
sucess.min(), sucess.max(), np.average(sucess)
# Out:
# (np.float32(-999.0), np.float32(1023.5), np.float32(5.725202))

# %%
for a, b in zip(original, sucess):
    print(a[0] == b[0], a[0], b[0])

# %%
for a, b in zip(original, sucess):
    for i in a:
        print(i, "\t", end="")
    print()
    for i in b:
        print(i, "\t", end="")
    print()
