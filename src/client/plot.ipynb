# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
path = Path("../../results/exploratory/").resolve()

# %%
for dir in path.iterdir():

    if not int(dir.stem.split("_")[0]) in range(150, 200):
        continue

    results = dir / "results.csv"

    if not results.exists():
        continue

    settings = dir / "settings.csv"

    for type in ["top_1", "top_5"]:
        df_results = pd.read_csv(results).replace(-1, np.nan)
        df_settings = pd.read_csv(settings)
        plt.figure(figsize=(10, 4))
        print()
        plt.title(
            type.upper().replace("_", " ")
            + " | "
            + df_settings["cfg_model"].item().split("/")[-1]
            + " | Image Count: "
            + str(df_settings["cfg_img_count"].item())
            + " | Samples: "
            + str(len(df_results[type]))
            + " | Failed: "
            + str(df_results[type].isna().sum().item())
            + "\n"
            + f"X: {df_settings.pos_x.item()} mm | Y: {df_settings.pos_y.item()} mm | Z: {df_settings.pos_z.item()} mm | U: {df_settings.cs_voltage.item()} V"
        )
        sns.histplot(df_results[type], bins=2**8, binrange=(0, 1))
        plt.tight_layout()
        plt.savefig((dir / f"{type}.svg"))
# Out:
# C:\Users\Steve\AppData\Local\Temp\ipykernel_13996\4048931169.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 4))

# %%
# for i in range(2, 5):
#     df = pd.read_csv(
#         f"../../results/exploratory/{str(i).zfill(4)}_spot/results.csv"
#     ).replace(-1, np.nan)

#     print(
#         pd.read_csv(f"../../results/exploratory/{str(i).zfill(4)}_spot/settings.csv")[
#             "cfg_model"
#         ].item()
#     )

#     print(
#         df["top_1"]
#         .value_counts(dropna=False)
#         .sort_index(ascending=False, na_position="first")
#         .to_markdown()
#     )

#     print("*" * 10)
#     # print(df["top_1"].isna().sum())

# %%
# for i in range(33, 34):
#     for type in ["top_1", "top_5"]:
#         results = pd.read_csv(
#             f"../../results/exploratory/{str(i).zfill(4)}_spot/results.csv"
#         ).replace(-1, np.nan)
#         settings = pd.read_csv(
#             f"../../results/exploratory/{str(i).zfill(4)}_spot/settings.csv"
#         )

#         target = settings["cfg_" + type].item()

#         results[type + "_diff"] = (df[type] - target) / target
#         sns.histplot(results[type + "_diff"], bins=100)

#         print(pd.cut(results[type + "_diff"], [0, 0.01, 0.1, 1, float("inf")]))

# %%
for dir in path.iterdir():

    if not int(dir.stem.split("_")[0]) in range(98, 200):
        continue

    results = dir / "results.csv"

    if not results.exists():
        continue

    settings = dir / "settings.csv"

    print(dir)
    print(pd.read_csv(settings).to_string())
# Out:
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0099_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25         -1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0100_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25         -1  /home/pincs/Desktop/src/models/resnet50.onnx            256            21    0.78125   0.945312
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0101_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25         -1  /home/pincs/Desktop/src/models/resnet50.onnx            128            21   0.757812     0.9375
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0102_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25         -1  /home/pincs/Desktop/src/models/resnet50.onnx             64            21     0.6875   0.953125
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0103_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0104_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25          1  /home/pincs/Desktop/src/models/resnet50.onnx            256            21    0.78125   0.945312
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0105_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25          1  /home/pincs/Desktop/src/models/resnet50.onnx            128            21   0.757812     0.9375
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0106_test
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1           ccw          right  123.4  155.1   0.25          1  /home/pincs/Desktop/src/models/resnet50.onnx             64            21     0.6875   0.953125
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0148_cw
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1            cw          right  124.5  154.2   0.25          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0151_cw
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1            cw          right  124.8  156.2   0.02          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0152_cw
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1            cw          right  124.6  156.2   0.18          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0153_cw
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         250          1       160            1           1            cw          right  123.3  155.0   0.15          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0154_cw
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         350          1       160            1           1            cw          right  124.3  156.2   0.29          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0157_cw_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         300          1       160            1           1            cw          right  122.0  156.0   0.15          1  /home/pincs/Desktop/src/models/resnet50.onnx            128            21   0.757812     0.9375
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0158_cw_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         300          1       160            1           1            cw          right  122.0  156.0   0.15          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0163_cw_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         300          1       160            1           1            cw          right  122.0  156.0   0.15          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0164_4mm_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         150          1        80            1           4           ccw          right  126.8  153.3   0.26          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0165_4mm_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         150          1        80            1           4           ccw          right  124.4  153.0   0.28          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0166_4mm_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         150          1        80            1           4           ccw          right  123.9  154.3   0.16          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0167_4mm_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         150          1        80            1           4           ccw          right  124.1  154.1   0.36          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
# C:\Users\Steve\CODE\drop\ncs2-emfi\results\exploratory\0168_4mm_optuna
#    cs_voltage  cs_repeat  cs_width  cs_deadtime  probe_core probe_winding probe_rotation  pos_x  pos_y  pos_z  cfg_delay                                     cfg_model  cfg_img_count  cfg_img_seed  cfg_top_1  cfg_top_5
# 0         150          1        80            1           4           ccw          right  124.4  153.0   0.28          1  /home/pincs/Desktop/src/models/resnet50.onnx            512            21    0.78125   0.935547
