# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for i in range(22, 35):
    for type in ["top_1", "top_5"]:
        df = pd.read_csv(
            f"../../results/exploratory/{str(i).zfill(4)}_spot/results.csv"
        ).replace(-1, np.nan)
        plt.figure(figsize=(10, 4))
        print()
        plt.title(
            type.upper().replace("_", " ")
            + " | "
            + pd.read_csv(
                f"../../results/exploratory/{str(i).zfill(4)}_spot/settings.csv"
            )["cfg_model"].item()
            + " | Samples: "
            + str(len(df[type]))
            + " | Failed: "
            + str(df[type].isna().sum().item())
        )
        sns.histplot(df[type], bins=2**6)
        plt.tight_layout()
        plt.savefig(f"../../results/exploratory/{str(i).zfill(4)}_spot/{type}.svg")
# Out:
# C:\Users\Steve\AppData\Local\Temp\ipykernel_29044\3640646304.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 4))

# %%
for i in range(2, 5):
    df = pd.read_csv(
        f"../../results/exploratory/{str(i).zfill(4)}_spot/results.csv"
    ).replace(-1, np.nan)

    print(
        pd.read_csv(f"../../results/exploratory/{str(i).zfill(4)}_spot/settings.csv")[
            "cfg_model"
        ].item()
    )

    print(
        df["top_1"]
        .value_counts(dropna=False)
        .sort_index(ascending=False, na_position="first")
        .to_markdown()
    )

    print("*" * 10)
    # print(df["top_1"].isna().sum())
# Out:
# /home/pincs/Desktop/src/models/resnet50.onnx
# |       top_1 |   count |
# |------------:|--------:|
# | nan         |      28 |
# |   0.785156  |       1 |
# |   0.78125   |      14 |
# |   0.777344  |      25 |
# |   0.773438  |      18 |
# |   0.769531  |      12 |
# |   0.765625  |       3 |
# |   0.761719  |       1 |
# |   0.257812  |       1 |
# |   0.132812  |       1 |
# |   0.121094  |       1 |
# |   0.09375   |       1 |
# |   0.0859375 |       1 |
# |   0.0742188 |       1 |
# |   0.0703125 |       4 |
# |   0.0664062 |       3 |
# |   0.0625    |       2 |
# |   0.0585938 |       2 |
# |   0.0546875 |       3 |
# |   0.0507812 |       2 |
# |   0.046875  |       4 |
# **********
# /home/pincs/Desktop/src/models/resnet18.onnx
# |       top_1 |   count |
# |------------:|--------:|
# | nan         |      22 |
# |   0.757812  |      41 |
# |   0.753906  |      31 |
# |   0.75      |      13 |
# |   0.746094  |       5 |
# |   0.742188  |       1 |
# |   0.738281  |       1 |
# |   0.28125   |       1 |
# |   0.269531  |       1 |
# |   0.164062  |       1 |
# |   0.160156  |       1 |
# |   0.152344  |       1 |
# |   0.148438  |       1 |
# |   0.144531  |       1 |
# |   0.136719  |       2 |
# |   0.132812  |       1 |
# |   0.125     |       1 |
# |   0.105469  |       2 |
# |   0.0859375 |       1 |
# **********
# /home/pincs/Desktop/src/models/vgg11.onnx
# |       top_1 |   count |
# |------------:|--------:|
# | nan         |      45 |
# |   0.75      |       2 |
# |   0.746094  |      18 |
# |   0.742188  |      22 |
# |   0.738281  |       8 |
# |   0.734375  |       2 |
# |   0.714844  |       1 |
# |   0.691406  |       1 |
# |   0.671875  |       2 |
# |   0.667969  |       2 |
# |   0.636719  |       1 |
# |   0.617188  |       1 |
# |   0.609375  |       1 |
# |   0.605469  |       1 |
# |   0.601562  |       2 |
# |   0.578125  |       1 |
# |   0.574219  |       1 |
# |   0.566406  |       1 |
# |   0.558594  |       1 |
# |   0.511719  |       1 |
# |   0.492188  |       1 |
# |   0.445312  |       1 |
# |   0.425781  |       1 |
# |   0.421875  |       1 |
# |   0.402344  |       1 |
# |   0.367188  |       1 |
# |   0.339844  |       1 |
# |   0.242188  |       1 |
# |   0.234375  |       1 |
# |   0.148438  |       1 |
# |   0.0507812 |       1 |
# |   0.046875  |       1 |
# |   0.0351562 |       1 |
# |   0.03125   |       1 |
# **********

# %%
for i in range(33, 34):
    for type in ["top_1", "top_5"]:
        results = pd.read_csv(
            f"../../results/exploratory/{str(i).zfill(4)}_spot/results.csv"
        ).replace(-1, np.nan)
        settings = pd.read_csv(
            f"../../results/exploratory/{str(i).zfill(4)}_spot/settings.csv"
        )
        
        target = settings["cfg_" + type].item()
        
        results[type + "_diff"] = (df[type] - target) / target
        sns.histplot(results[type + "_diff"],bins=100)
        
        print(pd.cut(results[type+"_diff"],[0, 0.01, 0.1, 1, float('inf')]))
